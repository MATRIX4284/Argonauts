# %%
#PDFs That faced Error
#url='./PDF_FOLDER/Narasimha_Karumanchi_DS_Algo.pdf' -- error
url="./PDF_FOLDER/Kubernetes_in_Action.pdf"

# %%
#PDF That were retrieved successfully
#url='./PDF_FOLDER/adaptive_pooling.pdf'
#url="./PDF_FOLDER/Neural_Nets_Tariq_Rashid.pdf"
#url="./PDF_FOLDER/Neural_Network_Learning_ theoretical_Foundations.pdf"  
url="./PDF_FOLDER/deeplearning_IAN_GOODFELLOW.pdf"

# %%
import pymupdf # imports the pymupdf library
import pandas as pd 
import fitz  # import PyMuPDF

import numpy as np


import numpy as np
import matplotlib.pyplot as plt
import os
import json

# %%
def show_image(item, title=""):
    """Display a pixmap.

    Just to display Pixmap image of "item" - ignore the man behind the curtain.

    Args:
        item: any PyMuPDF object having a "get_pixmap" method.
        title: a string to be used as image title

    Generates an RGB Pixmap from item using a constant DPI and using matplotlib
    to show it inline of the notebook.
    """
    DPI = 150  # use this resolution
    import numpy as np
    import matplotlib.pyplot as plt

    # %matplotlib inline
    pix = item.get_pixmap(dpi=DPI)
    img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
    plt.figure(dpi=DPI)  # set the figure's DPI
    plt.title(title)  # set title of image
    _ = plt.imshow(img, extent=(0, pix.w * 72 / DPI, pix.h * 72 / DPI, 0))

# %%
def download_images_per_page(doc,page,page_index,DPI):
    image_list = page.get_images()
    # print the number of images found on the page
    if image_list:
        print(f"Found {len(image_list)} images on page {page_index}")
    else:
        print("No images found on page", page_index)

    for image_index, img in enumerate(image_list, start=1): # enumerate the image list
        xref = img[0] # get the XREF of the image
        pix = pymupdf.Pixmap(doc, xref) # create a Pixmap

        ### Commented Out Section for showing images################################
        #if pix.n - pix.alpha > 3: # CMYK: convert to RGB first
        #    pix = pymupdf.Pixmap(pymupdf.csRGB, pix)            
        # %matplotlib inline
        #pix = item.get_pixmap(dpi=DPI)
        #img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
        #plt.figure(dpi=DPI)  # set the figure's DPI
        #plt.title(title)  # set title of image
        #_ = plt.imshow(img, extent=(0, pix.w * 72 / DPI, pix.h * 72 / DPI, 0))
        
        #############################################################################
            
        print('Image:')
        print(type(img))
            
        pix.save("page_%s-image_%s.png" % (page_index, image_index)) # save the image as png
        pix = None
        
    return True

# %%
def extract_images_per_page(doc,page_index,download):
    page_image_dict={}
    page_number=page_index+1
    page = doc[page_index] # get the page by index
    
    ####Get Images along with the metadata of it in the following order:
    #(xref, smask, width, height, bpc, colorspace, alt. colorspace, name, filter, referencer)
    #xref (int) is the image object number
    #smask (int) is the object number of its soft-mask image
    #width and height (ints) are the image dimensions
    #bpc (int) denotes the number of bits per component (normally 8)
    #colorspace (str) a string naming the colorspace (like DeviceRGB)
    #alt. colorspace (str) is any alternate colorspace depending on the value of colorspace
    #name (str) is the symbolic name by which the image is referenced
    #filter (str) is the decode filter of the image (Adobe PDF References, pp. 22).
    #referencer (int) the xref of the referencer. Zero if directly referenced by the page. Only present if full=True.
    
    image_list = page.get_images(full=True) #full=True as it will give the if any other pages are referencing
                                            #the image.
    
    #for image in image_list:
    #    xref, smask, width, height, bpc, colorspace, alt_colorspace, name, filter, referencer=image
    #    print("width")
    #    print(width)
    ###########################################################################################################
    
    img_cnt=len(image_list)
    npy_img_lst=[]
    DPI=150
    title=""
    ###########Extraction Of Images in Numpy Format############
    
    for image_index, img in enumerate(image_list, start=1): # enumerate the image list
        
            img_meta_dict={}
            
            xref = img[0] # get the XREF of the image
            
            smask= img[1] # Get Object number of the Soft Amsk of the Image
            
            width = img[2]
            print("width")
            print(width)
            
            height = img[3]
            print("height")
            print(height)
            
            num_bits = img[4] # Nuber of bits that is being used to represent the smallest component of the image
            colorspace = img[5] #colorspace of the image
            alt_colorspace = img[6] #colorspace of the image
            sym_name = img[7] #Symbolic name of the image
            img_filter = img[8] #decode filter of the image (Adobe PDF References, pp. 22)
            img_ref = img[9] #xref of the referencer. Zero if directly referenced by the page. 
                             #Only present if full=True.
            
            
            img_meta_dict["img_obj_num"]=xref
            img_meta_dict["smask_obj_num"]=smask
            img_meta_dict["width"]=width
            img_meta_dict["height"]=height
            img_meta_dict["num_bits"]=num_bits
            img_meta_dict["colorspace"]=colorspace
            img_meta_dict["alt_colorspace"]=alt_colorspace
            img_meta_dict["sym_name"]=sym_name
            img_meta_dict["filter"]=img_filter
            img_meta_dict["referencer"]=img_ref
            
            
            
            
            
            pix = pymupdf.Pixmap(doc, xref) # create a Pixmap
            
            
            
            ### Commented Out Section for showing images#############################

            #if pix.n - pix.alpha > 3: # CMYK: convert to RGB first
            #    pix = pymupdf.Pixmap(pymupdf.csRGB, pix)
            # %matplotlib inline
            #pix = item.get_pixmap(dpi=DPI)
            #img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
            #plt.figure(dpi=DPI)  # set the figure's DPI
            #plt.title(title)  # set title of image
            #_ = plt.imshow(img, extent=(0, pix.w * 18 / DPI, pix.h * 18 / DPI, 0))
            
            #############################################################################
            
            #print('Image:')
            #print(type(img))
            
            #Encode the Image into Base64

            #img_enc = base64.b64encode(img)
            
            #For Decoding use the following statement 
            
            #decoded_image = base64.decodestring(img_enc)
            
            img_meta_dict["img_matrix"]=img
            
            npy_img_lst.append(img_meta_dict)
            
            #pix.save("page_%s-image_%s.png" % (page_index, image_index)) # save the image as png
            #pix = None
            
    
    ###########################################################
    
    page_image_dict['page']=page_number
    page_image_dict['img_lst']=image_list
    page_image_dict['img_cnt']=len(image_list)
    page_image_dict['img_npy_lst']=npy_img_lst
    
    if download:
        download_images_per_page(doc,page,page_index,DPI)
    
    return page_image_dict


def extract_text_tables_images_per_page(doc,doc_img,index,download):
    page_dict={}
    page_image_dict={}
    tab_df_lst=[]
    page = doc[index]
    tabs = page.find_tables()  # detect the tables
    
    ##Extract Images From Pages############
    
    page_image_dict=extract_images_per_page(doc_img,index,download)
    
    print("page_image_dict")
    print(page_image_dict)
    
    
    page_dict['page']=page_image_dict['page']
    page_dict['img_lst']=page_image_dict['img_lst']
    
    
    
    
    
    page_dict['img_cnt']=page_image_dict['img_cnt']
    page_dict['img_npy_lst']=page_image_dict['img_npy_lst']
    
    #######################################
    
    for i,tab in enumerate(tabs):  # iterate over all tables
        for cell in tab.header.cells:
            page.draw_rect(cell,color=fitz.pdfcolor["red"],width=0.3)
        page.draw_rect(tab.bbox,color=fitz.pdfcolor["green"])
        print(f"Table {i} column names: {tab.header.names}, external: {tab.header.external}")
    
    #show_image(page, f"Table & Header BBoxes")
   
    # choose the second table for conversion to a DataFrame
    #tab = tabs[0]
    #print(tabs)
    
    if tabs.tables == []:
        print('Do Nothing')
    else:
        for tab in tabs:
            df=pd.DataFrame()
            df = tab.to_pandas()
            tab_df_lst.append(df)
    
    page_dict['tables']=tab_df_lst
    
    
    #Extract Text From each page
    text = page.get_text()
    page_dict['text']=text
    
    #print(tab_df_lst)
    #df = tab.to_pandas()
    # show the DataFrame
    return page_dict

# %%
#from numpyencoder import NumpyEncoder
import pickle

def extract_text_images_tables(doc_path,download=False):
    
    doc_per_page_tabs_lst=[]
    doc = fitz.open(doc_path)
    
    num_pages=len(doc)
    
    doc_img = pymupdf.open(doc_path)
    
    doc_name=url.split('/')[-1]
    
    doc_type=url.split('.')[-1]
    
    for i in range(3,num_pages):
        #page_image_dict={}
        tab_df_lst=extract_text_tables_images_per_page(doc,doc_img,i,download)
        
        if len(tab_df_lst) == 0:
            print("Do Nothing Here")
        else: 
            doc_per_page_tabs_lst.append(tab_df_lst)
    
    
    document_dictionary={"name":doc_name,"type":doc_type, "data": doc_per_page_tabs_lst}

    if download:
        #Save the List of MetaData to pickle in disk.
        with open(doc_name+'.pkl', 'wb') as f:
            pickle.dump(document_dictionary, f)
    
    return doc_per_page_tabs_lst

# %%
page_dict=extract_text_images_tables(url,download=True)
# Out:
# No images found on page 3
# page_image_dict
# {'page': 4, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 4
# page_image_dict
# {'page': 5, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 5
# page_image_dict
# {'page': 6, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 6
# page_image_dict
# {'page': 7, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 7
# page_image_dict
# {'page': 8, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 8
# page_image_dict
# {'page': 9, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 9
# page_image_dict
# {'page': 10, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 10
# page_image_dict
# {'page': 11, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 11
# page_image_dict
# {'page': 12, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 12
# page_image_dict
# {'page': 13, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 13
# page_image_dict
# {'page': 14, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 14
# page_image_dict
# {'page': 15, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 15
# page_image_dict
# {'page': 16, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 16
# page_image_dict
# {'page': 17, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 17
# page_image_dict
# {'page': 18, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 18
# page_image_dict
# {'page': 19, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 19
# page_image_dict
# {'page': 20, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 20
# page_image_dict
# {'page': 21, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 21
# page_image_dict
# {'page': 22, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 22
# page_image_dict
# {'page': 23, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 23
# page_image_dict
# {'page': 24, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 24
# page_image_dict
# {'page': 25, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 25
# page_image_dict
# {'page': 26, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 26
# page_image_dict
# {'page': 27, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 27
# page_image_dict
# {'page': 28, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 28
# page_image_dict
# {'page': 29, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 29
# page_image_dict
# {'page': 30, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# width
# 375
# height
# 513
# Found 1 images on page 30
# Image:
# <class 'tuple'>
# page_image_dict
# {'page': 31, 'img_lst': [(2471, 0, 375, 513, 8, 'DeviceRGB', '', 'Im1', 'FlateDecode', 0)], 'img_cnt': 1, 'img_npy_lst': [{'img_obj_num': 2471, 'smask_obj_num': 0, 'width': 375, 'height': 513, 'num_bits': 8, 'colorspace': 'DeviceRGB', 'alt_colorspace': '', 'sym_name': 'Im1', 'filter': 'FlateDecode', 'referencer': 0, 'img_matrix': (2471, 0, 375, 513, 8, 'DeviceRGB', '', 'Im1', 'FlateDecode', 0)}]}
# Do Nothing
# No images found on page 31
# page_image_dict
# {'page': 32, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 32
# page_image_dict
# {'page': 33, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 33
# page_image_dict
# {'page': 34, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# Do Nothing
# No images found on page 34
# page_image_dict
# {'page': 35, 'img_lst': [], 'img_cnt': 0, 'img_npy_lst': []}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_917283/1726702876.py in ?()
# ----> 1 page_dict=extract_text_images_tables(url,download=True)
#
# /tmp/ipykernel_917283/288383897.py in ?(doc_path, download)
#      15     doc_type=url.split('.')[-1]
#      16
#      17     for i in range(3,num_pages):
#      18         #page_image_dict={}
# ---> 19         tab_df_lst=extract_text_tables_images_per_page(doc,doc_img,i,download)
#      20
#      21         if len(tab_df_lst) == 0:
#      22             print("Do Nothing Here")
#
# /tmp/ipykernel_917283/3679285604.py in ?(doc, doc_img, index, download)
#     147     #######################################
#     148
#     149     for i,tab in enumerate(tabs):  # iterate over all tables
#     150         for cell in tab.header.cells:
# --> 151             page.draw_rect(cell,color=fitz.pdfcolor["red"],width=0.3)
#     152         page.draw_rect(tab.bbox,color=fitz.pdfcolor["green"])
#     153         print(f"Table {i} column names: {tab.header.names}, external: {tab.header.external}")
#     154
#
# ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/pymupdf/utils.py in ?(page, rect, color, fill, dashes, width, lineCap, lineJoin, morph, overlay, stroke_opacity, fill_opacity, oc, radius)
#    2159     '''
#    2160     Draw a rectangle. See Shape class method for details.
#    2161     '''
#    2162     img = page.new_shape()
# -> 2163     Q = img.draw_rect(pymupdf.Rect(rect), radius=radius)
#    2164     img.finish(
#    2165         color=color,
#    2166         fill=fill,
#
# ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/pymupdf/__init__.py in ?(self, p0, p1, x0, y0, x1, y1, *args)
#   11022
#   11023         Explicit keyword args p0, p1, x0, y0, x1, y1 override earlier settings
#   11024         if not None.
#   11025         """
# > 11026         x0, y0, x1, y1 = util_make_rect( *args, p0=p0, p1=p1, x0=x0, y0=y0, x1=x1, y1=y1)
#   11027         self.x0 = float( x0)
#   11028         self.y0 = float( y0)
#   11029         self.x1 = float( x1)
#
# ~/mambaforge-pypy3/envs/search_agent_poc/lib/python3.10/site-packages/pymupdf/__init__.py in ?(p0, p1, x0, y0, x1, y1, *args)
#   20252                 return args[0], args[1], x1, y1
#   20253         elif len(args) == 4:
#   20254             return args[0], args[1], args[2], args[3]
#   20255         raise Exception( f'Unrecognised args: {args}')
# > 20256     ret_x0, ret_y0, ret_x1, ret_y1 = handle_args()
#   20257     if p0 is not None:  ret_x0, ret_y0 = get_xy(p0)
#   20258     if p1 is not None:  ret_x1, ret_y1 = get_xy(p1)
#   20259     if x0 is not None:  ret_x0 = x0
#
# ValueError: not enough values to unpack (expected 4, got 1)
